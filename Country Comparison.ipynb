# %%
# Student Names
# Muscaan Balli - 23205368
# Rohit Sharma - 23200487
# Olumayokun Fadelu - 23201323
# Muhammad Usama Bhatti - 23202792

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating dataframes for Ireland and Denmark import/export
ireland_imports_exports = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Imports': [573371, 630897, 634839, 627517, 635418, 641586, 646283, 641459, 651536, 596798, 613984, 595333, 569706, 571329, 545993, 611024, 509811, 496339, 500918, 500234, 482976, 534949, 554135],
    'Exports': [-57572, -60846, -65754, -67975, -55090, -60590, -54166, -51068, -52310, -40346, -62640, -68656, -75765, -53067, -55936, -77738, -73780, -84344, -76806, -68501, -70870, -70456, -66858]
})

denmark_imports_exports = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Imports': [609261, 589363, 554451, 625455, 603192, 581666, 611622, 596983, 659524, 612557, 590586, 662990, 660088, 783921, 735950, 784679, 760952, 670574, 669945, 753650, 759161, 705782, 730518],
    'Exports': [-921848, -842993, -920302, -913639, -1019384, -1018240, -942396, -818832, -846958, -769798, -733849, -715012, -685066, -687509, -644320, -686961, -657135, -583382, -494731, -459873, -447960, -469166, -418032]
})

# Stacked bar chart
plt.figure(figsize=(12, 6))

years = ireland_imports_exports['Year']  # Assuming both dataframes have the same years

ireland_net_trade = ireland_imports_exports['Imports'] - ireland_imports_exports['Exports']
denmark_net_trade = denmark_imports_exports['Imports'] - denmark_imports_exports['Exports']

# Plotting Ireland trade
plt.bar(years, ireland_imports_exports['Exports'], label='Ireland Exports', color='green')
plt.bar(years, -ireland_imports_exports['Imports'], label='Ireland Imports', color='red')

# Plotting Denmark trade on top of Ireland trade
plt.bar(years, denmark_imports_exports['Exports'], label='Denmark Exports', color='lightgreen', alpha=0.7)
plt.bar(years, -denmark_imports_exports['Imports'], label='Denmark Imports', color='pink', alpha=0.7)

plt.title('Energy Import/Export: Ireland vs Denmark')
plt.xlabel('Year')
plt.ylabel('Energy (TJ)')
plt.legend(loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating dataframes for Ireland and Denmark
ireland_imports_exports = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Imports': [573371, 630897, 634839, 627517, 635418, 641586, 646283, 641459, 651536, 596798, 613984, 595333, 569706, 571329, 545993, 611024, 509811, 496339, 500918, 500234, 482976, 534949, 554135],
    'Exports': [-57572, -60846, -65754, -67975, -55090, -60590, -54166, -51068, -52310, -40346, -62640, -68656, -75765, -53067, -55936, -77738, -73780, -84344, -76806, -68501, -70870, -70456, -66858]
})

denmark_imports_exports = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Imports': [609261, 589363, 554451, 625455, 603192, 581666, 611622, 596983, 659524, 612557, 590586, 662990, 660088, 783921, 735950, 784679, 760952, 670574, 669945, 753650, 759161, 705782, 730518],
    'Exports': [-921848, -842993, -920302, -913639, -1019384, -1018240, -942396, -818832, -846958, -769798, -733849, -715012, -685066, -687509, -644320, -686961, -657135, -583382, -494731, -459873, -447960, -469166, -418032]
})

# Plotting
plt.figure(figsize=(12, 6))

# Ireland imports and exports
plt.plot(ireland_imports_exports['Year'], ireland_imports_exports['Imports'], label='Ireland Imports', linestyle='-', marker='o', color='blue')
plt.plot(ireland_imports_exports['Year'], ireland_imports_exports['Exports'], label='Ireland Exports', linestyle='-', marker='o', color='green')

# Denmark imports and exports
plt.plot(denmark_imports_exports['Year'], denmark_imports_exports['Imports'], label='Denmark Imports', linestyle='-', marker='o', color='red')
plt.plot(denmark_imports_exports['Year'], denmark_imports_exports['Exports'], label='Denmark Exports', linestyle='-', marker='o', color='orange')

plt.title('Energy Imports and Exports: Ireland vs Denmark')
plt.xlabel('Year')
plt.ylabel('Energy (TJ)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating dataframes for Ireland and Denmark total energy supply
ireland_total_energy_supply = pd.DataFrame({
    'Energy Source': ['Coal', 'Natural Gas', 'Hydro', 'Wind/Solar', 'Biofuels/Waste', 'Oil'],
    'Energy (TJ)': [44086, 186700, 2546, 41412, 32415, 254437]
})

denmark_total_energy_supply = pd.DataFrame({
    'Energy Source': ['Coal', 'Natural Gas', 'Hydro', 'Wind/Solar', 'Biofuels/Waste', 'Oil'],
    'Energy (TJ)': [44665, 60288, 68, 79290, 215289, 241347]
})

# Plotting
plt.figure(figsize=(12, 6))

# Number of groups and bar width
num_groups = len(ireland_total_energy_supply)
bar_width = 0.35

# Index for each bar
index = np.arange(num_groups)

# Plotting Ireland total energy supply
plt.bar(index, ireland_total_energy_supply['Energy (TJ)'], bar_width, label='Ireland')

# Plotting Denmark total energy supply
plt.bar(index + bar_width, denmark_total_energy_supply['Energy (TJ)'], bar_width, label='Denmark')

# X-axis labels
plt.xlabel('Energy Source')
plt.ylabel('Energy (TJ)')
plt.title('Total Energy Supply by Source: Ireland vs Denmark (2022)')
plt.xticks(index + bar_width / 2, ireland_total_energy_supply['Energy Source'], rotation=45)

# Adding legend
plt.legend()

# Displaying grid
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland and Denmark
ireland_renewables = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Modern_Renewables_Share': [0.15, 0.17, 0.19, 0.21, 0.23, 0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39, 0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59],
    'Renewables_Electricity_Share': [0.30, 0.32, 0.34, 0.36, 0.38, 0.40, 0.42, 0.44, 0.46, 0.48, 0.50, 0.52, 0.54, 0.56, 0.58, 0.60, 0.62, 0.64, 0.66, 0.68, 0.70, 0.72, 0.74]
})

denmark_renewables = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Modern_Renewables_Share': [0.25, 0.27, 0.29, 0.31, 0.33, 0.35, 0.37, 0.39, 0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69],
    'Renewables_Electricity_Share': [0.35, 0.37, 0.39, 0.41, 0.43, 0.45, 0.47, 0.49, 0.51, 0.53, 0.55, 0.57, 0.59, 0.61, 0.63, 0.65, 0.67, 0.69, 0.71, 0.73, 0.75, 0.77, 0.79]
})

# Plotting
plt.figure(figsize=(10, 6))

# Scatter plot for Ireland
plt.scatter(ireland_renewables['Modern_Renewables_Share'], ireland_renewables['Renewables_Electricity_Share'], label='Ireland', color='blue')

# Scatter plot for Denmark
plt.scatter(denmark_renewables['Modern_Renewables_Share'], denmark_renewables['Renewables_Electricity_Share'], label='Denmark', color='green')

plt.title('Renewables Share in Final Energy Consumption vs Electricity Generation')
plt.xlabel('Share of Modern Renewables in Final Energy Consumption')
plt.ylabel('Renewables Share of Electricity Generation')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland and Denmark
ireland_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'CO2_Emissions_per_Capita': [10.743, 11.127, 10.706, 10.499, 10.424, 10.65, 10.524, 10.053, 9.743, 8.652, 8.606, 7.76, 7.796, 7.484, 7.328, 7.545, 7.838, 7.474, 7.315, 6.881, 6.406, 6.705, 6.342]
})

denmark_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'CO2_Emissions_per_Capita': [9.515, 9.778, 9.689, 10.665, 9.591, 8.945, 10.373, 9.458, 8.863, 8.5, 8.523, 7.55, 6.645, 6.926, 6.147, 5.728, 5.928, 5.509, 5.481, 4.874, 4.45, 4.718, 4.42]
})

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(ireland_data['Year'], ireland_data['CO2_Emissions_per_Capita'], label='Ireland', marker='o')
plt.plot(denmark_data['Year'], denmark_data['CO2_Emissions_per_Capita'], label='Denmark', marker='o')

plt.title('CO2 Emissions per Capita: Ireland vs Denmark')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions per Capita (tCO2 / Capita)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland and Denmark
ireland_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'CO2_Emissions_per_Capita': [10.743, 11.127, 10.706, 10.499, 10.424, 10.65, 10.524, 10.053, 9.743, 8.652, 8.606, 7.76, 7.796, 7.484, 7.328, 7.545, 7.838, 7.474, 7.315, 6.881, 6.406, 6.705, 6.342]
})

denmark_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'CO2_Emissions_per_Capita': [9.515, 9.778, 9.689, 10.665, 9.591, 8.945, 10.373, 9.458, 8.863, 8.5, 8.523, 7.55, 6.645, 6.926, 6.147, 5.728, 5.928, 5.509, 5.481, 4.874, 4.45, 4.718, 4.42]
})

# Calculate cumulative emissions
ireland_cumulative = ireland_data['CO2_Emissions_per_Capita'].cumsum()
denmark_cumulative = denmark_data['CO2_Emissions_per_Capita'].cumsum()

# Plotting
plt.figure(figsize=(12, 8))

# Plotting stacked area chart
plt.fill_between(ireland_data['Year'], ireland_cumulative, label='Ireland', color='lightblue')
plt.fill_between(denmark_data['Year'], denmark_cumulative, label='Denmark', color='lightgreen')

# Customizing the plot
plt.title('Cumulative CO2 Emissions per Capita: Ireland vs Denmark')
plt.xlabel('Year')
plt.ylabel('Cumulative CO2 Emissions per Capita (tCO2 / Capita)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland
ireland_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Electricity_Consumption_per_Capita': [5.798, 5.9, 6.036, 6.092, 6.173, 6.242, 6.356, 6.332, 6.332, 5.944, 5.861, 5.596, 5.605, 5.659, 5.634, 5.745, 5.826, 5.835, 5.94, 5.953, 5.986, 6.188, 6.193]
})

# Data for Denmark
denmark_data = pd.DataFrame({
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Electricity_Consumption_per_Capita': [6.484, 6.492, 6.534, 6.603, 6.616, 6.66, 6.825, 6.67, 6.535, 6.22, 6.328, 6.167, 6.039, 6.041, 5.859, 5.823, 5.886, 5.885, 5.783, 5.753, 5.718, 6.16, 5.852]
})

# Plotting
plt.figure(figsize=(12, 8))

# Plotting Ireland data
plt.plot(ireland_data['Year'], ireland_data['Electricity_Consumption_per_Capita'], label='Ireland', marker='o')

# Plotting Denmark data
plt.plot(denmark_data['Year'], denmark_data['Electricity_Consumption_per_Capita'], label='Denmark', marker='o')

# Customizing the plot
plt.title('Electricity Consumption per Capita: Ireland vs Denmark (2021)')
plt.xlabel('Year')
plt.ylabel('Electricity Consumption per Capita (MWh / Capita)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland
ireland_data = pd.DataFrame({
    'Year': list(range(2000, 2023)),
    'Total_energy_supply_per_unit_of_GDP_Ireland': [
        1847.135, 1824.753, 1728.367, 1636.756, 1580.007, 1507.56, 1441.746, 1398.583, 1452.166, 1481.219, 
        1453.708, 1321.53, 1319.681, 1297.895, 1170.544, 981.777, 1008.966, 898.095, 841.036, 789.598, 
        720.385, 659.214, 574.376
    ]
})

# Data for Denmark
denmark_data = pd.DataFrame({
    'Year': list(range(2000, 2023)),
    'Total_energy_supply_per_unit_of_GDP_Denmark': [
        1838.148, 1879.609, 1850.588, 1949.401, 1836.776, 1742.823, 1801.081, 1743.223, 1702.312, 1726.042, 
        1772.234, 1615.792, 1544.525, 1538.354, 1425.439, 1386.62, 1374.012, 1347.557, 1316.083, 1250.095, 
        1223.975, 1229.234, 1134.143
    ]
})

# Plotting
plt.figure(figsize=(12, 8))

# Plotting Ireland data
plt.plot(ireland_data['Year'], ireland_data['Total_energy_supply_per_unit_of_GDP_Ireland'], label='Ireland')

# Plotting Denmark data
plt.plot(denmark_data['Year'], denmark_data['Total_energy_supply_per_unit_of_GDP_Denmark'], label='Denmark')

# Customizing the plot
plt.title('Total Energy Supply per Unit of GDP: Ireland vs Denmark (2000-2022)')
plt.xlabel('Year')
plt.ylabel('Total Energy Supply per Unit of GDP (MJ/thousand 2015 USD)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for Ireland
ireland_data = {
    'Year': list(range(2000, 2023)),
    'Renewables_share_of_electricity_generation_Ireland': [
        5, 4.2, 5.6, 4.6, 5.5, 7.3, 9.1, 9.9, 12, 14.7, 13.2, 20, 19.4, 22, 
        24.8, 28, 24.9, 29, 33, 38.4, 42.1, 36.8, 38.8
    ],
    'Share_of_modern_renewables_in_final_energy_consumption_Ireland': [
        None, None, None, None, None, None, None, None, None, None, None, 
        20, 19.4, 22, 24.8, 28, 24.9, 29, 33, 38.4, 42.1, 36.8, 38.8
    ]
}

# Data for Denmark
denmark_data = {
    'Year': list(range(2000, 2021)),
    'Renewables_share_of_electricity_generation_Denmark': [
        10.73, 11.11, 11.86, 12.71, 14.44, 16.12, 15.26, 17.69, 18.53, 19.33, 
        21.19, 23.82, 26.93, 27.05, 30.18, 32.53, 31.94, 35.02, 34.55, 37.29, 
        39.7
    ],
    'Share_of_modern_renewables_in_final_energy_consumption_Denmark': [
        10.73, 11.11, 11.86, 12.71, 14.44, 16.12, 15.26, 17.69, 18.53, 19.33, 
        21.19, 23.82, 26.93, 27.05, 30.18, 32.53, 31.94, 35.02, 34.55, 37.29, 
        39.7
    ]
}

# Combine data
ireland_df = pd.DataFrame(ireland_data)
denmark_df = pd.DataFrame(denmark_data)

# Plotting
plt.figure(figsize=(10, 6))

plt.scatter(ireland_df['Renewables_share_of_electricity_generation_Ireland'], 
            ireland_df['Share_of_modern_renewables_in_final_energy_consumption_Ireland'], 
            color='red', label='Ireland', marker='o')
plt.scatter(denmark_df['Renewables_share_of_electricity_generation_Denmark'], 
            denmark_df['Share_of_modern_renewables_in_final_energy_consumption_Denmark'], 
            color='blue', label='Denmark', marker='o')

plt.title('Renewables Share in Electricity Generation vs Final Energy Consumption')
plt.xlabel('Renewables share of electricity generation (%)')
plt.ylabel('Share of modern renewables in final energy consumption (%)')
plt.legend()
plt.grid(True)
plt.show()
